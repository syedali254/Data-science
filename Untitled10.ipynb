# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs 
from sklearn.cluster import KMeans

x,labels=make_blobs(n_samples=200,centers=3,cluster_std=1.0,random_state=42)
kmeans=KMeans(n_clusters=3,n_init=10,random_state=42)

cluster_assignments = kmeans.fit_predict(x)  #trains and predicts the points at oce

print(kmeans.inertia_)

print(silhouette_score(x, cluster_assignments))
# Out:
# 364.4733211131726
# 0.8467003894636074

# %%
centroids = kmeans.cluster_centers_

# 5. Plot the results
plt.figure(figsize=(7, 5))
# Color the scatter points based on their assigned cluster labels
plt.scatter(x[:, 0], x[:, 1], c=cluster_assignments, cmap='viridis', alpha=0.6, label='Data Points')
# Mark the final centroid locations with red crosses
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')

plt.title("Level 1: Minimalist K-Means Clustering")
plt.legend()
plt.show()
