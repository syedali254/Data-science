# %%
import numpy as np

data=np.array([10,32,15,61])
print(np.mean(data))
# Out:
# 29.5

# %%
import numpy as np
import pandas as pd

# %%
import numpy as np
import pandas as pd

df=pd.read_csv("Titanic-Dataset.csv")

df.head()
print(np.mean(df["Age"]))
# Out:
# 29.69911764705882

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df["Fare"],bins=[i for i in range(0,100,20)])
plt.show()

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns


df=pd.read_csv("Titanic-Dataset.csv")

df.head()
print(np.mean(df["Age"]))

mn=np.mean(df["Age"])


sns.histplot(x="Age",data=df,bins=[i for i in range(0,80,5)])
plt.plot([mn for i in range(300)],[i for i in range(300)])
plt.show()
# Out:
# 29.69911764705882

# %%
df["Age"].fillna(df["Age"].mean(),inplace=True)
df.isnull().sum()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_16184\3975819558.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(),inplace=True)
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(np.median(df["Fare"]))
# Out:
# 14.4542

# %%
med=np.median(df["Fare"])

sns.histplot(x="Fare",data=df,bins=[i for i in range(0,80,5)])
plt.plot([med for i in range(300)],[i for i in range(300)])
plt.show()

# %%
print(df["Sex"].mode()[0])
# Out:
# male

# %%
print(df["Sex"].value_counts())
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
print((df["Age"].max()-df["Age"].min()))
# Out:
# 79.58

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sec_a=np.array([75,65,73,68,72,76])
sec_b=np.array([90,47,43,96,93,51])
no=np.array([1,2,3,4,5,6])
mean_a=np.mean(sec_a)
mead_b=np.mean(sec_b)

# %%
plt.figure(figsize=(10,3))
plt.scatter(sec_a,no,label="Sec A")
plt.scatter(sec_b,no,label="Sec B")
plt.legend()
plt.show()

# %%
mad_a=np.sum(np.abs(sec_a-mean_a))/len(sec_a)
print(mad_a)
# Out:
# 3.3333333333333335

# %%
mad_b=np.sum(np.abs(sec_b-mead_b))/len(sec_b)
print(mad_b)
# Out:
# 23.0

# %%
print(len(df["Age"]))
# Out:
# 891

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
print(np.percentile(df["Age"],75))
# Out:
# 35.0

# %%
q1=np.percentile(df["Age"],25)
q2=np.percentile(df["Age"],50)
q3=np.percentile(df["Age"],75)
iqr=q3-q1
low=q1-1.5*iqr
high=q3+1.5*iqr
print(low,high)
# Out:
# 2.5 54.5

# %%
print(f"otliers are: ",df[(df["Age"] < low) | (df["Age"] > high)])
# Out:
# otliers are:       PassengerId  Survived  Pclass  \
# 7              8         0       3
# 11            12         1       1
# 15            16         1       2
# 16            17         0       3
# 33            34         0       2
# ..           ...       ...     ...
# 827          828         1       2
# 829          830         1       1
# 831          832         1       2
# 851          852         0       3
# 879          880         1       1
#
#                                               Name     Sex    Age  SibSp  \
# 7                   Palsson, Master. Gosta Leonard    male   2.00      3
# 11                        Bonnell, Miss. Elizabeth  female  58.00      0
# 15                Hewlett, Mrs. (Mary D Kingcome)   female  55.00      0
# 16                            Rice, Master. Eugene    male   2.00      4
# 33                           Wheadon, Mr. Edward H    male  66.00      0
# ..                                             ...     ...    ...    ...
# ...

# %%
plt.boxplot(x="Age",data=df)
plt.show()

# %%
print(df["Age"].skew())    #measure the skewness of how uneven the data is it must be skew=0 so ml model can be trained perfectly
# Out:
# 0.4344880940129925

# %%
sns.histplot(df["Age"],bins=[i for i in range(0,80,5)])
plt.show()

# %%
x=np.percentile(df["Age"],75)
print(x)
# Out:
# nan

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#---------------------------------Covariance and Correlations------------------

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df2=pd.read_csv("tip.csv")
print(df2.head(5))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(df2.isnull().sum())
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df2.select_dtypes(["float64","int64"]).corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
df2.select_dtypes(["float64","int64"]).cov()
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
import numpy as np
np.cov(df2["total_bill"],df2["tip"])  #covariance b/w 2 columns using np
# Out:
# array([[79.25293861,  8.32350163],
#        [ 8.32350163,  1.91445464]])

# %%
cor_data=np.corrcoef(df2["total_bill"],df2["tip"])

# %%
print(cor_data)
plt.figure(figsize=(4,3))
sns.heatmap(cor_data,annot=True)
plt.show()
# Out:
# [[1.         0.67573411]
#  [0.67573411 1.        ]]

# %%
plt.figure(figsize=(4,3))
cov_data=np.cov(df2["total_bill"],df2["tip"])
sns.heatmap(cov_data,annot=True)
plt.show()

# %%
#----------------------Central limit theorem------------ when very large population data to find mean divide into samples and then take mean

# %%
pop_data =[np.random.randint(10,100) for i in range(10000)]

# %%
df3=pd.DataFrame({"pop_data":pop_data})
df3

# %%
plt.figure(figsize=(3,2))  # bcz according to CLT if data is normal or non normal and you want to find a mean so u do this by finding means of samples
sns.kdeplot(df3["pop_data"]) # so lets say we take a non normal population
plt.show()

# %%
sample_mean=[]

for no_samples in range(70):
    sample_data=[]
    for data in range(500):
        sample_data.append(np.random.choice(pop_data))
    sample_mean.append(np.mean(sample_data))

sm=pd.DataFrame({"sample_mean":sample_mean})
sns.kdeplot(x="sample_mean",data=sm)
plt.show()

# %%
np.mean(pop_data)
# Out:
# np.float64(54.4759)

# %%
np.mean(sample_mean)
# Out:
# np.float64(54.576657142857144)
