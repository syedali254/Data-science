# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score



#1 synthetic Dataset

np.random.seed(42)

n=150
aws_bills=np.random.uniform(5000,100000,150)
ping_pong=np.random.randint(0,11,n)

scores=(aws_bills/5000)+(ping_pong*0.5) +np.random.normal(0,0.8,n)


labels=np.where(scores>13,"Succes","flop")

df=pd.DataFrame({
    'AWS_Bill':aws_bills,
    'Ping_Pong':ping_pong,
    'status':labels,
})
print(df.head(4))
X=df[['AWS_Bill','Ping_Pong']]
Y=df['status']

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

knn=KNeighborsClassifier(n_neighbors=3,metric='euclidean')
knn.fit(X_train_scaled,Y_train)

pred=knn.predict(X_test)
acc=accuracy_score(Y_test,pred)
print("accuracy is: ",acc)
# Out:
#        AWS_Bill  Ping_Pong  status
# 0  40581.311290          0    flop
# 1  95317.859109          0  Succes
# 2  74539.424472          2  Succes
# 3  61872.555999          1    flop
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 33
#      30 X=df[['AWS_Bill','Ping_Pong']]
#      31 Y=df['status']
# ---> 33 X_train_X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
#      35 scaler=StandardScaler()
#      36 X_train_scaled=scaler.fit_transform(X_train)
#
# ValueError: too many values to unpack (expected 3)
