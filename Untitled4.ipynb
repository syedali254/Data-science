# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score

# 1. Make dataset
data = {
    'AWS_Bill_USD': [1500, 50000, 200, 80000, 1200, 60000, 300, 90000],
    'Ping_Pong_Tables': [1, 5, 0, 8, 2, 6, 1, 10],
    'Status': ['Flop', 'Unicorn', 'Flop', 'Unicorn', 'Flop', 'Unicorn', 'Flop', 'Unicorn']
}

df = pd.DataFrame(data)

# 2. Separate X and Y
X = df[['AWS_Bill_USD', 'Ping_Pong_Tables']]
Y = df['Status']

# 3. Train-test split
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)

# 4. Feature scaling
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 5. Create KNN model
knn = KNeighborsClassifier(n_neighbors=3, metric='euclidean')

# 6. Train model
knn.fit(X_train_scaled, Y_train)

# 7. Predict
pred = knn.predict(X_test_scaled)

# 8. Accuracy
acc = accuracy_score(Y_test, pred)

print("Accuracy score is:", acc)

# 9. Detailed report
print(classification_report(Y_test, pred))
# Out:
# Accuracy score is: 0.5
#               precision    recall  f1-score   support
#
#         Flop       0.00      0.00      0.00         0
#      Unicorn       1.00      0.50      0.67         2
#
#     accuracy                           0.50         2
#    macro avg       0.50      0.25      0.33         2
# weighted avg       1.00      0.50      0.67         2
# C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Hp\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
numbers=np.random.randint(0,10,5)
noise=np.random.normal(0,0.5,5)
print(numbers)
print(noise)
print(numbers+noise)
# Out:
# [2 2 5 1 1]
# [ 0.10506434 -0.06787755 -0.65529548  0.19743044  0.04868912]
# [2.10506434 1.93212245 4.34470452 1.19743044 1.04868912]
