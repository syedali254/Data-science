# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier


np.random.seed(42)
n=200
cgpa=np.random.normal(2.9,0.7,n)

Dsa_skill=np.random.uniform(4,10,n)
internships=np.random.randint(1,5,n)
projects=np.random.randint(1,6,n)


placement_score=(cgpa*0.4)+(Dsa_skill*2)+(internships*0.3)+(projects*0.1)
score=placement_score+(np.random.normal(0,1.5,n))
status=np.where(score>18,"placed","not placed")


df=pd.DataFrame({
    'cgpa':cgpa,
    'Dsa_skill':Dsa_skill,
    'internships':internships,
    'projects':projects,
    'status':status,
})
print(df.head(5))

X=df.drop(['status'],axis=1)
Y=df['status']
scaler=StandardScaler()

X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_scaled,Y_train)

train_acc=knn.score(X_train_scaled,Y_train)
test_acc=knn.score(X_test_scaled,Y_test)
print("train acc is : ",train_acc)
print("test acc is: ",test_acc)



import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['Dsa_skill'])
plt.show()

plt.scatter(X_train_scaled[:,0],X_train_scaled[:,1])
plt.show()
# Out:
#        cgpa  Dsa_skill  internships  projects      status
# 0  3.247700   9.264238            2         2      placed
# 1  2.803215   8.444612            1         2      placed
# 2  3.353382   8.182094            3         2      placed
# 3  3.966121   8.214905            4         3      placed
# 4  2.736093   6.156947            1         3  not placed
# train acc is :  0.91875
# test acc is:  0.9
