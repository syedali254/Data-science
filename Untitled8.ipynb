# %%
import matplotlib.pyplot as plt


k=[1,2,3,4,5]

train_acc=[100,96,94,93,91]

plt.plot(k,train_acc,marker='o',color='blue',linestyle='-')
plt.show()

# %%
import numpy as np
ed_lvl=np.random.choice(
    [0,1,2,3],
    size=10,
    p=[0.25,0.45,0.20,0.10]
)
print(ed_lvl)
# Out:
# [1 2 0 1 3 2 1 0 0 0]
